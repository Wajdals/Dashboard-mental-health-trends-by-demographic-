# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Mental Health Dataset.csv')
df
# Out:
#               Timestamp  Gender        Country Occupation self_employed  \
# 0       8/27/2014 11:29  Female  United States  Corporate           NaN
# 1       8/27/2014 11:31  Female  United States  Corporate           NaN
# 2       8/27/2014 11:32  Female  United States  Corporate           NaN
# 3       8/27/2014 11:37  Female  United States  Corporate            No
# 4       8/27/2014 11:43  Female  United States  Corporate            No
# ...                 ...     ...            ...        ...           ...
# 146891  8/27/2014 21:35    Male         Canada   Business            No
# 146892  8/27/2014 21:39    Male  United States   Business            No
# 146893  8/27/2014 21:45    Male      Singapore   Business            No
# 146894  8/27/2014 21:54    Male      Australia   Business            No
# 146895  8/27/2014 22:00    Male  United States   Business            No
#
#        family_history treatment      Days_Indoors Growing_Stress  \
# 0                  No       Yes         1-14 days            Yes
# 1                 Yes       Yes         1-14 days            Yes
# 2                 Yes       Yes         1-14 days            Yes
# 3                 Yes       Yes         1-14 days            Yes
# 4                 Yes       Yes         1-14 days            Yes
# ...               ...       ...               ...            ...
# 146891             No       Yes  Go out Every day          Maybe
# 146892             No        No  Go out Every day          Maybe
# 146893             No        No  Go out Every day          Maybe
# 146894             No       Yes  Go out Every day          Maybe
# 146895              Y       NaN               NaN            NaN
#
#        Changes_Habits Mental_Health_History Mood_Swings Coping_Struggles  \
# 0                  No                   Yes      Medium               No
# 1                  No                   Yes      Medium               No
# 2                  No                   Yes      Medium               No
# 3                  No                   Yes      Medium               No
# 4                  No                   Yes      Medium               No
# ...               ...                   ...         ...              ...
# 146891            Yes                   Yes        High              Yes
# 146892            Yes                   Yes        High              Yes
# 146893            Yes                   Yes        High              Yes
# 146894            Yes                   Yes        High              Yes
# 146895            NaN                   NaN         NaN              NaN
#
#        Work_Interest Social_Weakness mental_health_interview care_options
# 0                 No             Yes                      No     Not sure
# 1                 No             Yes                      No           No
# 2                 No             Yes                      No          Yes
# 3                 No             Yes                   Maybe          Yes
# 4                 No             Yes                      No          Yes
# ...              ...             ...                     ...          ...
# 146891         Maybe              No                      No     Not sure
# 146892         Maybe              No                   Maybe          Yes
# 146893         Maybe              No                      No           No
# 146894         Maybe              No                      No           No
# 146895           NaN             NaN                     NaN          NaN
#
# [146896 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146896 entries, 0 to 146895
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Timestamp                146896 non-null  object
#  1   Gender                   146896 non-null  object
#  2   Country                  146896 non-null  object
#  3   Occupation               146896 non-null  object
#  4   self_employed            144054 non-null  object
#  5   family_history           146896 non-null  object
#  6   treatment                146895 non-null  object
#  7   Days_Indoors             146895 non-null  object
#  8   Growing_Stress           146895 non-null  object
#  9   Changes_Habits           146895 non-null  object
#  10  Mental_Health_History    146895 non-null  object
#  11  Mood_Swings              146895 non-null  object
#  12  Coping_Struggles         146895 non-null  object
#  13  Work_Interest            146895 non-null  object
#  14  Social_Weakness          146895 non-null  object
#  15  mental_health_interview  146895 non-null  object
#  16  care_options             146895 non-null  object
# dtypes: object(17)
# memory usage: 19.1+ MB

# %%
df.isnull().sum()
# Out:
# Timestamp                     0
# Gender                        0
# Country                       0
# Occupation                    0
# self_employed              2842
# family_history                0
# treatment                     1
# Days_Indoors                  1
# Growing_Stress                1
# Changes_Habits                1
# Mental_Health_History         1
# Mood_Swings                   1
# Coping_Struggles              1
# Work_Interest                 1
# Social_Weakness               1
# mental_health_interview       1
# care_options                  1
# dtype: int64

# %%
df['self_employed'].value_counts()
# Out:
# self_employed
# No     130738
# Yes     13316
# Name: count, dtype: int64

# %%
df['self_employed'].fillna("null", inplace= True)

# %%
df.isnull().sum()
# Out:
# Timestamp                  0
# Gender                     0
# Country                    0
# Occupation                 0
# self_employed              0
# family_history             0
# treatment                  1
# Days_Indoors               1
# Growing_Stress             1
# Changes_Habits             1
# Mental_Health_History      1
# Mood_Swings                1
# Coping_Struggles           1
# Work_Interest              1
# Social_Weakness            1
# mental_health_interview    1
# care_options               1
# dtype: int64

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# Timestamp                  0
# Gender                     0
# Country                    0
# Occupation                 0
# self_employed              0
# family_history             0
# treatment                  0
# Days_Indoors               0
# Growing_Stress             0
# Changes_Habits             0
# Mental_Health_History      0
# Mood_Swings                0
# Coping_Struggles           0
# Work_Interest              0
# Social_Weakness            0
# mental_health_interview    0
# care_options               0
# dtype: int64

# %%
df.describe()
# Out:
#               Timestamp  Gender        Country Occupation self_employed  \
# count            146896  146896         146896     146896        146896
# unique              580       2             35          5             3
# top     8/27/2014 11:43    Male  United States  Corporate            No
# freq               1204   94382          88995      31709        130738
#
#        family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# count          146896    146895       146895         146895         146895
# unique              3         2            5              3              3
# top                No       Yes   31-60 days            Yes            Yes
# freq            82231     80182        32415          52298          54459
#
#        Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# count                 146895      146895           146895        146895
# unique                     3           3                2             3
# top                    Maybe      Medium               No         Maybe
# freq                   51098       51249            77453         52886
#
#        Social_Weakness mental_health_interview care_options
# count           146895                  146895       146895
# unique               3                       3            3
# top              Maybe                      No           No
# freq             53578                  120041        55743

# %%
df.to_csv('Mental Health Dataset 1.csv', index= True )
